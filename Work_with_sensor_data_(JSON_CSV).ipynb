# %% [markdown]
# <a href="https://colab.research.google.com/github/jahirr01/understanding-the-concepts-of-ML/blob/main/Work_with_sensor_data_(JSON_CSV).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Basic CSV Parsing Code

# %%
import csv

# Open CSV file
with open("iot_device_data.csv", "r") as file:
    reader = csv.DictReader(file)

    # Loop through each row
    for row in reader:
        device_id = row["device_id"]
        temperature = float(row["temperature"])
        humidity = float(row["humidity"])
        usage_hours = int(row["usage_hours"])
        error_count = int(row["error_count"])
        vibration = float(row["vibration"])
        device_status = row["device_status"]

        print("Device ID:", device_id)
        print("Temperature:", temperature)
        print("Humidity:", humidity)
        print("Usage Hours:", usage_hours)
        print("Error Count:", error_count)
        print("Vibration:", vibration)
        print("Status:", device_status)
        print("---------------------------")
# Out:
# Device ID: D101
# Temperature: 57.0
# Humidity: 41.0
# Usage Hours: 24
# Error Count: 4
# Vibration: 0.44
# Status: warning
# ---------------------------
# Device ID: D102
# Temperature: 32.0
# Humidity: 46.0
# Usage Hours: 22
# Error Count: 1
# Vibration: 0.93
# Status: normal
# ---------------------------
# Device ID: D103
# Temperature: 26.6
# Humidity: 45.0
# Usage Hours: 7
# Error Count: 3
# Vibration: 0.81
# Status: warning
# ---------------------------
# Device ID: D104
# Temperature: 26.3
# Humidity: 52.0
# Usage Hours: 23
# Error Count: 6
# Vibration: 0.41
# Status: failure
# ---------------------------
# Device ID: D105
# Temperature: 54.5
# Humidity: 40.0
# Usage Hours: 6
# Error Count: 6
# Vibration: 0.58
# Status: failure
# ---------------------------
# Device ID: D106
# Temperature: 32.8
# Humidity: 88.0
# Usage Hours: 11
# Error Count: 1
# Vibration: 0.23
# Status: normal
# ---------------------------
# Device ID: D107
# Temperature: 29.8
# Humidity: 62.0
# ...

# %% [markdown]
# Using numpy and pandas libries with data cleaning and feature Extraction
